# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV, ShuffleSplit
from sklearn.svm import SVR, SVC
from utils import read_neutouch_raw, infer, bin_neutouch_signal

# %%
tool_length = 50
trial = 10
df_raw = read_neutouch_raw(f'/datasets/sensory_ext/data/neutouch/tool_neutouch_1k/trial{trial}_{tool_length}.tact')
# df_raw = df_raw.iloc[10000:250000]
df_essentials = pd.read_csv(f'/datasets/sensory_ext/data/neutouch/tool_neutouch_1k/trial{trial}_{tool_length}_essentials.csv')
#df_essentials = df_essentials.iloc[:9]
df_essentials = df_essentials[df_essentials.t <= df_raw.t.iloc[-1]]

# %%
tapped_times = df_essentials.t.values
len(tapped_times)
# Out:
# 100

# %%
#df_raw.isPos[df_raw.isPos == 0] = -1
fig, ax =plt.subplots(figsize=(15,7))
ax.plot(df_raw.t.values, df_raw.isPos.cumsum().values)
ax.plot(df_essentials.t, np.zeros(df_essentials.t.shape), 'rx')
ax.plot(where_happened, np.zeros(len(where_happened)), 'gx')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4dc43077e75d> in <module>
#       3 ax.plot(df_raw.t.values, df_raw.isPos.cumsum().values)
#       4 ax.plot(df_essentials.t, np.zeros(df_essentials.t.shape), 'rx')
# ----> 5 ax.plot(where_happened, np.zeros(len(where_happened)), 'gx')
#       6 plt.show()
#
# NameError: name 'where_happened' is not defined

# %%
time_past = 0.05
time_future = 0.25
tap_time = tapped_times[0]
df_timespan = df_raw[(df_raw.t >= (tap_time - time_past)) & (df_raw.t < (tap_time + time_future))]

# %%
plt.plot(df_timespan.t, df_timespan.isPos.cumsum())
plt.plot(tap_time, 1, 'rx')

# %%
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    
    real_diff = np.abs(array[idx] - value)
    return array[idx], real_diff

# %%
raw_file = open(f'/datasets/sensory_ext/data/neutouch/tool_neutouch_1k/trial{trial}_{tool_length}.tact', 'r')
Lines = raw_file.readlines()

# %%
# do inference:
all_sample_dfs = []
df_timespans = []
my_ffts = []
def inference(t):
    sample_df = read_neutouch_raw("temp_signal.tact")
    signal, ss = bin_neutouch_signal(t, sample_df, 0.05, 0.25, 0.005)
    df_timespans.append(ss)
    res, my_fft = infer(signal, tool_length)
    #print('Predicted tap location:', res[0], t )
    #print(signal.shape)
    all_sample_dfs.append(sample_df)
    my_ffts.append(my_fft)
    return res[0]
    
def inference2(t):
    df_timespan = df_raw[(df_raw.t >= (t - time_past)) & (df_raw.t < (t + time_future))]
    signal, ss = bin_neutouch_signal(t, df_timespan, 0.05, 0.25, 0.005)
    res, my_fft = infer(signal, tool_length)
    return res[0]

# %%
DIFF_THRESHOLD = -50
window_size = 1000
waiting_time = 2

# %%
window = []
temp_f = open("temp_signal.tact", "w")
info = []
last_detection = 0.0
update_time = 0.0
where_happened = []
all_count = 0

recorded_time =[]
for i, line in enumerate(Lines):
    isPos, index, _, t = line.split(' ')
    
#     if i < 10000:
#         continue
#     if i >= 270000:
#         break
    
    isPos = int(isPos)
    index = int(index)
    t = float(t)
    
    if not temp_f.closed:
        temp_f.write(str(isPos)+' '+str(index) + ' 1 ' +str(t)+'\n')
    
    if (t-last_detection) < waiting_time:
        
        if update_time <= t:
            # need to infer here
            # publish here
            if not temp_f.closed:
                temp_f.close()
                #print('found at', all_count,'closed at t', t, 'prediction: ')
                print('My prediction is:', inference(last_detection) )
                
                real_time, delta = find_nearest(  df_essentials.t.values, last_detection )
                if delta < 1.0:
                    print('Real prediction is:', inference2(df_essentials[df_essentials.t == real_time].t.values[0]) )
                
                all_count+=1
        continue
        

    if last_detection < t + waiting_time:
        if temp_f.closed:
            temp_f = open("temp_signal.tact", "w")
    # detection_procedure
    
    if len(window) < window_size:
        window.append(isPos)
    else:
        window.pop(0)
        window.append(isPos)
        
    pos = len( [x for x in window if x == 1] )
    neg = len( [x for x in window if x == 0] )
    
    recorded_time.append(t)
    info.append((pos,neg))
    
    if (pos-neg) < DIFF_THRESHOLD:
        where_happened.append(t-0.03)
        print('----------------- detected:')
        last_detection = t-0.03
        update_time = t+0.3
        window = []
    
    #print(pos, neg)
# Out:
# ----------------- detected:
# My prediction is: 26.366645283919752
# Real prediction is: 24.65965098017503
# ----------------- detected:
# My prediction is: 20.079357732296884
# Real prediction is: 18.00854531040501
# ----------------- detected:
# My prediction is: 29.579125493516237
# Real prediction is: 31.018044177936616
# ----------------- detected:
# My prediction is: 23.67727970819884
# Real prediction is: 18.49789488983131
# ----------------- detected:
# My prediction is: 34.89589064339068
# Real prediction is: 34.48035224107889
# ----------------- detected:
# My prediction is: 17.877455952357046
# Real prediction is: 14.53527382597405
# ----------------- detected:
# My prediction is: 37.041037068305
# Real prediction is: 37.50541681585622
# ----------------- detected:
# My prediction is: 17.59950395659534
# Real prediction is: 13.661066558452497
# ----------------- detected:
# My prediction is: 41.5525987977838
# Real prediction is: 37.411144567108515
# ----------------- detected:
# My prediction is: 26.222580424324992
# Real prediction is: 23.008182865561995
# ----------------- detected:
# My prediction is: 14.676524402679192
# Real prediction is: 11.823537458805797
# ----------------- detected:
# My prediction is: 24.99516860697654
# Real prediction is: 21.001128792517495
# ----------------- detected:
# My prediction is: 25.044665919129205
# Real prediction is: 25.167641593717853
# ----------------- detected:
# My prediction is: 33.450320702899006
# Real prediction is: 34.69061679039212
# ----------------- detected:
# My prediction is: 17.527085689736126
# Real prediction is: 11.576128224108619
# ----------------- detected:
# My prediction is: 23.711458441255
# Real prediction is: 19.6069646949668
# ----------------- detected:
# My prediction is: 28.936821483597193
# Real prediction is: 26.065642417607588
# ----------------- detected:
# My prediction is: 34.268694870718654
# Real prediction is: 34.811507067421836
# ----------------- detected:
# My prediction is: 14.422484977360174
# Real prediction is: 11.749943210712415
# ----------------- detected:
# My prediction is: 26.20103792411036
# Real prediction is: 23.759646387673317
# ----------------- detected:
# My prediction is: 17.289360886939427
# Real prediction is: 10.765318217329803
# ----------------- detected:
# My prediction is: 17.797213054523393
# Real prediction is: 12.761090963463749
# ----------------- detected:
# My prediction is: 26.762926076618314
# Real prediction is: 21.25976944511823
# ----------------- detected:
# My prediction is: 29.025070049860133
# Real prediction is: 29.25001711595356
# ----------------- detected:
# My prediction is: 14.975758878600724
# Real prediction is: 11.988728475550095
# ----------------- detected:
# Real prediction is: 17.96149674621129
# ----------------- detected:
# My prediction is: 8.063023899728606
# Real prediction is: 6.902861591419397
# ----------------- detected:
# My prediction is: 24.762546933349533
# Real prediction is: 22.168264432933505
# ----------------- detected:
# My prediction is: 28.820604663232807
# Real prediction is: 25.507054317452013

# %%
recorded_time[-1] - where_happened[-1]
# Out:
# 20.43871808052063

# %%
len(where_happened)
# Out:
# 100

# %%
df_essentials
# Out:
#     original_index             t   label_y
# 0              508  1.613134e+09  0.299262
# 1              601  1.613134e+09  0.179085
# 2              687  1.613134e+09  0.309180
# 3              777  1.613134e+09  0.185982
# 4              863  1.613134e+09  0.343800
# ..             ...           ...       ...
# 95            8993  1.613135e+09  0.165898
# 96            9082  1.613135e+09  0.092677
# 97            9172  1.613135e+09  0.193262
# 98            9260  1.613135e+09  0.256070
# 99            1213  1.613134e+09  0.399247
#
# [100 rows x 3 columns]

# %%
info = np.array(info)
a  = info[:,0]-info[:,1]

# %%
a.shape
# Out:
# (376145,)

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.plot(recorded_time,  a)
ax.plot(df_essentials.t, np.zeros(len(df_essentials.t)), 'rx')
ax.plot(where_happened, np.zeros(len(where_happened)), 'gx')
ax.set_ylim([-100,20])
# Out:
# (-100.0, 20.0)

# %%
df_essentials.t.values - np.array(where_happened)
# Out:
# array([-1.50232315e-02, -2.98941135e-02,  7.41648674e-03, -3.96029949e-02,
#        -4.93836403e-03, -2.76691914e-02, -1.94406509e-03, -1.69324875e-02,
#         2.99098730e+00,  2.94066596e+00,  2.99690366e+00,  2.94086289e+00,
#         2.98486042e+00,  3.02299476e+00,  2.85595202e+00,  3.08096266e+00,
#         3.14610124e+00,  2.85144114e+00,  2.91176677e+00,  3.14610314e+00,
#         3.06742835e+00,  2.92001987e+00,  2.95278621e+00,  3.00021625e+00,
#         3.01206326e+00,  3.00674987e+00,  2.71915174e+00,  3.00768566e+00,
#         3.00225377e+00,  3.02872372e+00,  3.13181877e+00,  2.84249473e+00,
#         3.10673213e+00,  2.87700772e+00,  3.28605437e+00,  2.84258270e+00,
#         2.87465930e+00,  2.98052573e+00,  2.93795943e+00,  2.96154308e+00,
#         2.96209598e+00,  2.91267014e+00,  2.93934822e+00,  2.96704555e+00,
#         3.18622231e+00,  2.87162566e+00,  3.12296772e+00,  2.90995193e+00,
#         2.95045137e+00,  2.93221116e+00,  2.99719596e+00,  3.17894936e+00,
#         2.83140779e+00,  2.95710683e+00,  3.09517002e+00,  2.87540722e+00,
#         2.93655729e+00,  3.05166078e+00,  2.91778183e+00,  2.98595786e+00,
#         3.02710128e+00,  3.03661537e+00,  2.83636522e+00,  3.00547171e+00,
#         2.85685539e+00,  3.02299690e+00,  3.17194152e+00,  2.76997948e+00,
#         2.98473263e+00,  2.96911383e+00,  3.16540813e+00,  3.01076913e+00,
#         2.81652069e+00,  2.99970579e+00,  2.93236160e+00,  3.01647663e+00,
#         3.03503609e+00,  2.92463493e+00,  3.03597736e+00,  2.93099260e+00,
#         3.31995583e+00,  3.07675123e+00,  2.91638160e+00,  2.90488791e+00,
#         2.85280108e+00,  3.11435843e+00,  2.82474327e+00,  3.23129463e+00,
#         2.82999158e+00,  3.01383829e+00,  2.97146392e+00,  3.06931686e+00,
#         2.83137703e+00,  2.90426254e+00,  2.98104453e+00,  3.16007257e+00,
#         3.00680399e+00,  3.03515267e+00,  2.96486831e+00, -2.73746220e+02])

# %%
df_essentials.t.values[3]
# Out:
# 1613134477.5083294

# %%
where_happened
# Out:
# [1613134468.3746216,
#  1613134471.5513077,
#  1613134474.441963,
#  1613134477.5479324,
#  1613134480.4372427,
#  1613134483.4540017,
#  1613134486.3552947,
#  1613134489.2941265,
#  1613134492.4071493,
#  1613134495.41639,
#  1613134498.3861184,
#  1613134501.402114,
#  1613134504.3841035,
#  1613134507.3719,
#  1613134510.4288974,
#  1613134513.301821,
#  1613134516.4006882,
#  1613134519.5513093,
#  1613134522.4150293,
#  1613134525.3425167,
#  1613134528.516154,
#  1613134531.622888,
#  1613134534.5837426,
#  1613134537.5292764,
#  1613134540.5443628,
#  1613134543.576629,
#  1613134546.6522217,
#  1613134549.3886075,
#  1613134552.4211323,
#  1613134555.4555275,
#  1613134558.515399,
#  1613134561.6946518,
#  1613134564.524481,
#  1613134567.6430593,
#  1613134570.5339694,
#  1613134573.8314102,
#  1613134576.6892712,
#  1613134579.5773566,
#  1613134582.5838888,
#  1613134585.5522416,
#  1613134588.5776603,
#  1613134591.5510402,
#  1613134594.4823673,
#  1613134597.4465857,
#  1613134600.4254017,
#  1613134603.6289818,
#  1613134606.5385826,
#  1613134609.6756504,
#  1613134612.6249552,
#  1613134615.5671585,
#  1613134618.4951692,
#  1613134621.5123355,
#  1613134624.7189574,
#  1613134627.5861342,
#  1613134630.5790203,
#  1613134633.692204,
#  1613134636.55758,
#  1613134639.4993963,
#  1613134642.5922387,
#  1613134645.5529995,
#  1613134648.571825,
#  1613134651.6242611,
#  1613134654.6804733,
#  1613134657.5393486,
#  1613134660.5440068,
#  1613134663.439737,
#  1613134666.4867692,
#  1613134669.67672,
#  1613134672.4878712,
#  1613134675.495457,
#  1613134678.495103,
#  1613134681.6776943,
#  1613134684.7269042,
#  1613134687.5386972,
#  1613134690.5679784,
#  1613134693.5098486,
#  1613134696.5502448,
#  1613134699.6200438,
#  1613134702.5681784,
#  1613134705.6311688,
#  1613134708.6081197,
#  1613134711.9473243,
#  1613134715.0336416,
#  1613134717.9711702,
#  1613134720.9151275,
#  1613134723.8155272,
#  1613134726.9641187,
#  1613134729.8305018,
#  1613134733.0887842,
#  1613134735.9298847,
#  1613134738.9642098,
#  1613134741.9603276,
#  1613134745.0542436,
#  1613134747.9053032,
#  1613134750.8224778,
#  1613134753.805465,
#  1613134756.9826035,
#  1613134760.013208,
#  1613134763.077464,
#  1613134766.0844154]

# %%
sample_id = 0
plt.plot(df_timespans[sample_id].t, df_timespans[sample_id].isPos.cumsum(), 'g-')
plt.plot(where_happened[sample_id], 1, 'gx')


tap_time = tapped_times[sample_id]
df_timespan = df_raw[(df_raw.t >= (tap_time - time_past)) & (df_raw.t < (tap_time + time_future))]

plt.plot(df_timespan.t, df_timespan.isPos.cumsum(), 'r-')
plt.plot(tap_time, 1, 'rx')

# %%
all_sample_dfs[0].t[0]
# Out:
# 1613134451.1127193

# %%
df_timespan.t.iloc[0]
# Out:
# 1613134468.309857

# %%
time_future
# Out:
# 0.25

# %%
tap_time = tapped_times[3]
#df_timespan = df_raw[(df_raw.t >= (tap_time - time_past)) & (df_raw.t < (tap_time + time_future))]
#print(df_timespan.shape)
infer( bin_neutouch_signal(tap_time, df_raw, 0.05, 0.25,0.005)[0] )
# Out:
# (array([18.49789489]),
#  array([[0.007     , 0.0196778 , 0.0178301 , ..., 0.00747226, 0.00865035,
#          0.00775392]]))

# %%
df_essentials
# Out:
#     original_index             t   label_y
# 0              508  1.613134e+09  0.299262
# 1              601  1.613134e+09  0.179085
# 2              687  1.613134e+09  0.309180
# 3              777  1.613134e+09  0.185982
# 4              863  1.613134e+09  0.343800
# ..             ...           ...       ...
# 95            8993  1.613135e+09  0.165898
# 96            9082  1.613135e+09  0.092677
# 97            9172  1.613135e+09  0.193262
# 98            9260  1.613135e+09  0.256070
# 99            1213  1.613134e+09  0.399247
#
# [100 rows x 3 columns]

# %%
tapped_times = df_essentials.t.values

all_values = []
old_ffts = []
for i, row in df_essentials.iterrows():
    t, label  = row.t, row.label_y
    y_pred, old_fft = infer( bin_neutouch_signal(t, df_raw, 0.05, 0.25, 0.005)[0], tool_length)
    all_values.append([label, y_pred])
    old_ffts.append(old_fft)

# %%
all_values
# Out:
# [[0.2992622595647691, array([24.65965098])],
#  [0.1790845658997414, array([18.00854531])],
#  [0.3091802601138471, array([31.01804418])],
#  [0.185982194207084, array([18.49789489])],
#  [0.3438003309438346, array([34.48035224])],
#  [0.1463564899186013, array([14.53527383])],
#  [0.3762535475561736, array([37.50541682])],
#  [0.135614436529052, array([13.66106656])],
#  [0.1804076698044656, array([23.00818287])],
#  [0.1192383434990762, array([11.82353746])],
#  [0.1781218167761681, array([21.00112879])],
#  [0.2601851713279603, array([25.16764159])],
#  [0.3686832188995896, array([34.69061679])],
#  [0.114759933612716, array([11.57612822])],
#  [0.1950698312739251, array([19.60696469])],
#  [0.2596522163967011, array([26.06564242])],
#  [0.3430731486896394, array([34.81150707])],
#  [0.1164967384556649, array([11.74994321])],
#  [0.219868313930404, array([23.75964639])],
#  [0.1066497680167077, array([10.76531822])],
#  [0.1266081300000069, array([12.76109096])],
#  [0.1938781854132531, array([21.25976945])],
#  [0.2914991420129655, array([29.25001712])],
#  [0.1208884086827157, array([11.98872848])],
#  [0.1838820394495843, array([18.48822089])],
#  [0.2401175540307877, array([24.1114619])],
#  [0.1004983600596307, array([9.94963774])],
#  [0.2428697165469048, array([24.38708767])],
#  [0.1015065726260064, array([10.2503132])],
#  [0.2398679223278878, array([23.88657562])],
#  [0.1177904125670312, array([11.87897974])],
#  [0.4058058116952298, array([40.48046374])],
#  [0.3250028457859872, array([32.60039963])],
#  [0.2148454007128594, array([21.58423636])],
#  [0.1424134638527749, array([14.34099279])],
#  [0.0931271132449029, array([9.41276017])],
#  [0.1329427626351235, array([13.39387917])],
#  [0.162192475459945, array([16.294982])],
#  [0.148727532885444, array([18.50103964])],
#  [0.2666964497784493, array([20.67020273])],
#  [0.1136556681612847, array([11.26523481])],
#  [0.2716218795994637, array([27.26217325])],
#  [0.1383021887759087, array([13.72983406])],
#  [0.3045797761896966, array([30.5581808])],
#  [0.1428334679821847, array([14.38328404])],
#  [0.1610891785839913, array([17.36458005])],
#  [0.2367246564844964, array([23.77257176])],
#  [0.1569534507016061, array([15.59538784])],
#  [0.3002557348827241, array([30.12587594])],
#  [0.4160735275963662, array([41.50728233])],
#  [0.1777301099518655, array([17.87318746])],
#  [0.0998796936491845, array([9.88805546])],
#  [0.1415204223612664, array([14.64974149])],
#  [0.2073930617789147, array([20.63905945])],
#  [0.2481081154564736, array([24.91089091])],
#  [0.3382190674910663, array([32.88840249])],
#  [0.4249901403108952, array([36.1284331])],
#  [0.1983268078783868, array([19.73233544])],
#  [0.1080055352667687, array([10.90068925])],
#  [0.2374413278321145, array([23.64382344])],
#  [0.0978161212424157, array([9.8818028])],
#  [0.2395842340210793, array([24.05878388])],
#  [0.1071811732272027, array([10.8182764])],
#  [0.3019119020918725, array([27.46082241])],
#  [0.1022406336287377, array([10.32422393])],
#  [0.1609764662007211, array([15.99736591])],
#  [0.2852880176524041, array([28.62886035])],
#  [0.1205519404629586, array([11.95533682])],
#  [0.3274880987028001, array([32.64866764])],
#  [0.0990199264506219, array([9.80192663])],
#  [0.2714283880213616, array([27.24280025])],
#  [0.0954614695528863, array([9.64622321])],
#  [0.3062028330186723, array([30.72027536])],
#  [0.0970312472800133, array([9.80311634])],
#  [0.3688542888867078, array([36.9858551])],
#  [0.2771145295719026, array([27.81167738])],
#  [0.2050150301674722, array([20.60118626])],
#  [0.1269276257971642, array([12.79249381])],
#  [0.1927582290390847, array([19.37575052])],
#  [0.2605142411211846, array([25.95145139])],
#  [0.1485059824208138, array([14.95012458])],
#  [0.1253708567837594, array([12.63719115])],
#  [0.2381875779847024, array([23.71861602])],
#  [0.1146520790079949, array([11.36486458])],
#  [0.2867960822204469, array([25.30434957])],
#  [0.1405494775990365, array([13.98157193])],
#  [0.2124208327750085, array([21.34208796])],
#  [0.0962893780688164, array([9.60896203])],
#  [0.282246742806804, array([27.86940483])],
#  [0.3680130605953155, array([36.6044896])],
#  [0.1916115399817345, array([18.48191771])],
#  [0.136727285049331, array([13.77293638])],
#  [0.1785314944008706, array([17.75288342])],
#  [0.3016791981080888, array([30.06792829])],
#  [0.3369280662754891, array([33.59273409])],
#  [0.1658980813244698, array([17.96149675])],
#  [0.0926772471884606, array([6.90286159])],
#  [0.1932615604618905, array([22.16826443])],
#  [0.2560703646758912, array([25.50705432])],
#  [0.3992468420783399, array([37.41114457])]]

# %%
from sklearn.metrics import euclidean_distances

# %%
euclidean_distances( old_ffts[0], old_ffts[1])
# Out:
# array([[0.10143196]])

# %%
euclidean_distances( old_ffts[0], my_ffts[0])
# Out:
# array([[0.04768289]])
