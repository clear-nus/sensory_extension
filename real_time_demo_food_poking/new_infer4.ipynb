# %%
import pandas as pd
import numpy as np
from utils import read_neutouch_adc
import matplotlib.pyplot as plt

pd.options.mode.chained_assignment = None  # default='warn'

# %%
objs = ['cucumber', 'watermelon', 'tofu', 'pressedtofu']
iters = 15
data_dir = 'data/new_data'

def filter_taxels(sample, threshold=300):
    mask = (sample.adc > -100)
    for taxel in range(1,81):
        subsample = df[sample.taxel == taxel]
        if subsample.shape[0] > 0:
            if subsample.adc.iloc[0] >= threshold:
                mask &= ~(sample.taxel==taxel)
    return sample[mask]

# %%
#collect all data
info = {}

for obj in objs:
    info[obj] = []
    for i in range(1111, 1136):
        if obj == 'cucumber':
            if i == 1115:
                break
        if obj == 'watermelon':
            if i == 1126:
                break
        if obj == 'tofu':
            if i == 1126:
                break
        fname = f'{data_dir}/{obj}_zero_{i}.tact'
        df = read_neutouch_adc(fname)
        df = df[(df.taxel >= 1) & (df.taxel <=80)]
        df = filter_taxels(df)
        info[obj].append(df)

# %%
# see tofus
for i in range(7):
    sample = info['pressedtofu'][i]
    fig, ax = plt.subplots(figsize=(15,5))
    for taxel in sample.taxel.unique():
        ax.plot(sample[sample.taxel == taxel].t, sample[sample.taxel == taxel].adc)
        ax.set_title(str(i))
    plt.show()

# %%
# can I detect the water?

def isCucumber(sample, threshold_unique_taxels=15, threshold_time=3.9):
    
    a = sample[sample.t >= threshold_time]

    if len(a.taxel.unique()) >= threshold_unique_taxels:
        return 0
    
    return 1

# def isDragonfruit(sample, threshold_unique_taxels=5, threshold_diff_adc=5 ):

#     a = sample[['taxel', 'adc']].groupby(['taxel']).agg(['max', 'min', 'std'])
#     a.columns = a.columns.map('_'.join)
#     a = a.assign(diversion = a.adc_max.subtract(a.adc_min))

    
#     if ( a[a.diversion >= threshold_diff_adc].shape[0] ) <= threshold_unique_taxels:
#         return 1
        
#     return 0

# can I detect the tofu?

def isTofu(sample, threshold_unique_taxels=6, threshold_diff_adc=12):
    
    if isCucumber(sample) == 1:
        return 0

    a = sample[['taxel', 'adc']].groupby(['taxel']).agg(['max', 'min', 'std'])
    a.columns = a.columns.map('_'.join)
    a = a.assign(diversion = a.adc_max.subtract(a.adc_min))

    #print(a[a.diversion >= threshold_diff_adc].shape[0], threshold_unique_taxels)

    
    if a[a.diversion >= threshold_diff_adc].shape[0] >= threshold_unique_taxels:
        return 0
    
    return 1

# can I detect pressed tofu?

def isPressedTofu(sample, threshold_unique_taxels=8, threshold_diff_adc=20):
    if isCucumber(sample) == 1:
        return 0
    if isTofu(sample) == 1:
        return 0
    
    a = sample[['taxel', 'adc']].groupby(['taxel']).agg(['max', 'min', 'std'])
    a.columns = a.columns.map('_'.join)
    a = a.assign(diversion = a.adc_max.subtract(a.adc_min))
    
    if a[a.diversion >= threshold_diff_adc].shape[0] >= threshold_unique_taxels:
        return 0
    
    return 1
    
    

def integrate(sample):
    delta_times = sample.t.diff().fillna(0).values
    adc = sample.adc.values
    res = delta_times*adc
    return np.sum(res)

def isWatermelon(sample, threshold_unique_taxels=15, threshold_time=3.9):
    
    if isCucumber(sample) == 1:
        return 0
    
    if isPressedTofu(sample) == 1:
        return 0
    
    if isTofu(sample) == 1:
        return 0
    
    #a = sample[sample.t >= threshold_time]
    
    #if len(a.taxel.unique()) >= threshold_unique_taxels:
    #    return 1
    
    return 1

# %%
obj = 'cucumber'
for i in range(4):
    print(f'{obj} check at {i}: {isWatermelon(info[obj][i])}, {isTofu(info[obj][i])}, {isPressedTofu(info[obj][i])}, {isCucumber(info[obj][i])}')
# Out:
# cucumber check at 0: 0, 0, 0, 1
# cucumber check at 1: 0, 0, 0, 1
# cucumber check at 2: 0, 0, 0, 1
# cucumber check at 3: 0, 0, 0, 1

# %%
for obj in info.keys():
    for i in range(len(info[obj])):
        print(f'{obj} check at {i}: {isWatermelon(info[obj][i])}, {isTofu(info[obj][i])}, {isPressedTofu(info[obj][i])}, {isCucumber(info[obj][i])}')
# Out:
# cucumber check at 0: 0, 0, 0, 1
# cucumber check at 1: 0, 0, 0, 1
# cucumber check at 2: 0, 0, 0, 1
# cucumber check at 3: 0, 0, 0, 1
# watermelon check at 0: 1, 0, 0, 0
# watermelon check at 1: 1, 0, 0, 0
# watermelon check at 2: 1, 0, 0, 0
# watermelon check at 3: 1, 0, 0, 0
# watermelon check at 4: 1, 0, 0, 0
# watermelon check at 5: 1, 0, 0, 0
# watermelon check at 6: 1, 0, 0, 0
# watermelon check at 7: 1, 0, 0, 0
# watermelon check at 8: 1, 0, 0, 0
# watermelon check at 9: 1, 0, 0, 0
# watermelon check at 10: 0, 0, 1, 0
# watermelon check at 11: 0, 0, 1, 0
# watermelon check at 12: 1, 0, 0, 0
# watermelon check at 13: 0, 0, 1, 0
# watermelon check at 14: 1, 0, 0, 0
# tofu check at 0: 0, 1, 0, 0
# tofu check at 1: 0, 1, 0, 0
# tofu check at 2: 0, 1, 0, 0
# tofu check at 3: 0, 1, 0, 0
# tofu check at 4: 0, 1, 0, 0
# tofu check at 5: 0, 1, 0, 0
# tofu check at 6: 0, 1, 0, 0
# tofu check at 7: 0, 1, 0, 0
# tofu check at 8: 0, 0, 1, 0
# tofu check at 9: 0, 1, 0, 0
# tofu check at 10: 0, 1, 0, 0
# tofu check at 11: 0, 1, 0, 0
# tofu check at 12: 0, 1, 0, 0
# tofu check at 13: 0, 1, 0, 0
# tofu check at 14: 0, 1, 0, 0
# pressedtofu check at 0: 0, 1, 0, 0
# pressedtofu check at 1: 1, 0, 0, 0
# pressedtofu check at 2: 1, 0, 0, 0
# pressedtofu check at 3: 0, 1, 0, 0
# pressedtofu check at 4: 0, 1, 0, 0
# pressedtofu check at 5: 0, 0, 1, 0
# pressedtofu check at 6: 0, 0, 1, 0
# pressedtofu check at 7: 0, 0, 1, 0
# pressedtofu check at 8: 0, 0, 1, 0
# pressedtofu check at 9: 0, 0, 1, 0
# pressedtofu check at 10: 0, 0, 1, 0
# pressedtofu check at 11: 1, 0, 0, 0
# pressedtofu check at 12: 0, 0, 1, 0
# pressedtofu check at 13: 0, 0, 1, 0
# pressedtofu check at 14: 1, 0, 0, 0
# pressedtofu check at 15: 0, 0, 1, 0
# pressedtofu check at 16: 1, 0, 0, 0
# pressedtofu check at 17: 0, 0, 1, 0
# pressedtofu check at 18: 0, 0, 1, 0
# pressedtofu check at 19: 0, 0, 1, 0
# pressedtofu check at 20: 0, 0, 1, 0
# pressedtofu check at 21: 0, 0, 1, 0
# pressedtofu check at 22: 0, 0, 1, 0
# pressedtofu check at 23: 0, 0, 1, 0
# pressedtofu check at 24: 0, 0, 1, 0

# %%
for obj in ['watermelon']:#info.keys():
    for i in range(iters):
        isWatermelon(info[obj][i])
        #print(f'{obj} check at {i}: {isWater(info[obj][i])}, {isTofu(info[obj][i])}')

# %%
for obj in info.keys():
    for i in range(iters):
        print(f'{obj} check at {i}: {isWater(info[obj][i])}, {isTofu(info[obj][i])}')

# %%
# sample = info['water'][7]
# fig, ax = plt.subplots(figsize=(15,10))
# for taxel in sample.taxel.unique():
#     ax.plot(sample[sample.taxel == taxel].t, sample[sample.taxel == taxel].adc)
#     ax.set_title(str(i))
# plt.show()

# %%
sample = info['tofu'][7]
fig, ax = plt.subplots(figsize=(15,10))
for taxel in sample.taxel.unique():
    ax.plot(sample[sample.taxel == taxel].t, sample[sample.taxel == taxel].adc)
    ax.set_title(str(i))
plt.show()
